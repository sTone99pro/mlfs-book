# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"> **Air Quality** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 04: Batch Inference</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Download model and batch inference data
# 2. Make predictions, generate PNG for forecast
# 3. Store predictions in a monitoring feature group adn generate PNG for hindcast

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import sys
from pathlib import Path

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml


if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Read the API keys and configuration variables from the file <root_dir>/.env
from mlfs import config
settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/pppanda/mlfs-book
# HopsworksSettings initialized!

# %%
import datetime
import pandas as pd
from xgboost import XGBRegressor
import hopsworks
import json
from mlfs.airquality import util
import os

# %%
today = datetime.datetime.now() - datetime.timedelta(0)
tomorrow = today + datetime.timedelta(days = 1)
today
# Out:
# datetime.datetime(2025, 11, 12, 16, 19, 37, 638577)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
project = hopsworks.login(engine="python")
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# 2025-11-12 16:19:37,644 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2025-11-12 16:19:37,646 INFO: Initializing external client
# 2025-11-12 16:19:37,646 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-12 16:19:38,222 WARNING: UserWarning: The installed hopsworks client version 4.4.2 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-12 16:19:39,063 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1282196

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Download the model from Model Registry</span>

# %%
mr = project.get_model_registry()

retrieved_model = mr.get_model(
    name="air_quality_xgboost_model",
    version=1,
)

fv = retrieved_model.get_feature_view()

# Download the saved model artifacts to a local directory
saved_model_dir = retrieved_model.download()
# Out:
# 2025-11-12 16:19:43,762 INFO: Initializing for batch retrieval of feature vectors
# Downloading: 0.000%|          | 0/516304 elapsed<00:00 remaining<?
# Downloading model artifact (0 dirs, 1 files)...
# Downloading: 0.000%|          | 0/108168 elapsed<00:00 remaining<?
# Downloading model artifact (0 dirs, 2 files)...
# Downloading: 0.000%|          | 0/19642 elapsed<00:00 remaining<?
# Downloading model artifact (1 dirs, 3 files)... DONE

# %%
# Loading the XGBoost regressor model and label encoder from the saved model directory
# retrieved_xgboost_model = joblib.load(saved_model_dir + "/xgboost_regressor.pkl")
retrieved_xgboost_model = XGBRegressor()

retrieved_xgboost_model.load_model(saved_model_dir + "/model.json")

# Displaying the retrieved XGBoost regressor model
retrieved_xgboost_model
# Out:
# XGBRegressor(base_score='8.400252E1', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              feature_types=['float', 'float', 'float', 'float'], gamma=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## <span style="color:#ff5f27;">✨ Get Weather Forecast Features with Feature View   </span>

# %%
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)
batch_data = weather_fg.filter(weather_fg.date >= today).read()
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.71s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-15 00:00:00+00:00                15.20                0.0
# 1 2025-11-18 00:00:00+00:00                 5.05                0.0
# 2 2025-11-13 00:00:00+00:00                14.60                0.0
# 3 2025-11-17 00:00:00+00:00                 7.15                0.0
# 4 2025-11-14 00:00:00+00:00                13.45                0.0
# 5 2025-11-16 00:00:00+00:00                17.65                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city
# 0            6.569383                    80.537750  Shanghai
# 1            9.832680                   293.749512  Shanghai
# 2           10.182337                   351.869995  Shanghai
# 3           14.689588                   323.972534  Shanghai
# 4            6.638072                    40.601215  Shanghai
# 5            9.339208                    27.552727  Shanghai

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Making the predictions</span>

# %%
batch_data['predicted_pm25'] = retrieved_xgboost_model.predict(
    batch_data[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant']])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-15 00:00:00+00:00                15.20                0.0
# 1 2025-11-18 00:00:00+00:00                 5.05                0.0
# 2 2025-11-13 00:00:00+00:00                14.60                0.0
# 3 2025-11-17 00:00:00+00:00                 7.15                0.0
# 4 2025-11-14 00:00:00+00:00                13.45                0.0
# 5 2025-11-16 00:00:00+00:00                17.65                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25
# 0            6.569383                    80.537750  Shanghai       91.209328
# 1            9.832680                   293.749512  Shanghai       95.855614
# 2           10.182337                   351.869995  Shanghai      105.202896
# 3           14.689588                   323.972534  Shanghai      129.659988
# 4            6.638072                    40.601215  Shanghai       93.547844
# 5            9.339208                    27.552727  Shanghai      115.651505

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         6 non-null      datetime64[us, Etc/UTC]
#  1   temperature_2m_mean          6 non-null      float32
#  2   precipitation_sum            6 non-null      float32
#  3   wind_speed_10m_max           6 non-null      float32
#  4   wind_direction_10m_dominant  6 non-null      float32
#  5   city                         6 non-null      object
#  6   predicted_pm25               6 non-null      float32
# dtypes: datetime64[us, Etc/UTC](1), float32(5), object(1)
# memory usage: 344.0+ bytes

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Saving the predictions (for monitoring) to a Feature Group</span>

# %%
batch_data['street'] = street
batch_data['city'] = city
batch_data['country'] = country
# Fill in the number of days before the date on which you made the forecast (base_date)
batch_data['days_before_forecast_day'] = range(1, len(batch_data)+1)
batch_data = batch_data.sort_values(by=['date'])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 2 2025-11-13 00:00:00+00:00                14.60                0.0
# 4 2025-11-14 00:00:00+00:00                13.45                0.0
# 0 2025-11-15 00:00:00+00:00                15.20                0.0
# 5 2025-11-16 00:00:00+00:00                17.65                0.0
# 3 2025-11-17 00:00:00+00:00                 7.15                0.0
# 1 2025-11-18 00:00:00+00:00                 5.05                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25  \
# 2           10.182337                   351.869995  Shanghai      105.202896
# 4            6.638072                    40.601215  Shanghai       93.547844
# 0            6.569383                    80.537750  Shanghai       91.209328
# 5            9.339208                    27.552727  Shanghai      115.651505
# 3           14.689588                   323.972534  Shanghai      129.659988
# 1            9.832680                   293.749512  Shanghai       95.855614
#
#              street country  days_before_forecast_day
# 2  Jiading Nanxiang   China                         3
# 4  Jiading Nanxiang   China                         5
# 0  Jiading Nanxiang   China                         1
# 5  Jiading Nanxiang   China                         6
# 3  Jiading Nanxiang   China                         4
# 1  Jiading Nanxiang   China                         2

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 2 to 1
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         6 non-null      datetime64[us, Etc/UTC]
#  1   temperature_2m_mean          6 non-null      float32
#  2   precipitation_sum            6 non-null      float32
#  3   wind_speed_10m_max           6 non-null      float32
#  4   wind_direction_10m_dominant  6 non-null      float32
#  5   city                         6 non-null      object
#  6   predicted_pm25               6 non-null      float32
#  7   street                       6 non-null      object
#  8   country                      6 non-null      object
#  9   days_before_forecast_day     6 non-null      int64
# dtypes: datetime64[us, Etc/UTC](1), float32(5), int64(1), object(3)
# memory usage: 408.0+ bytes

# %% [markdown]
# ### Create Forecast Graph
# Draw a graph of the predictions with dates as a PNG and save it to the github repo
# Show it on github pages

# %%
pred_file_path = f"{root_dir}/docs/air-quality/assets/img/pm25_forecast.png"
plt = util.plot_air_quality_forecast(city, street, batch_data, pred_file_path)

plt.show()

# %%
# Get or create feature group
monitor_fg = fs.get_or_create_feature_group(
    name='aq_predictions',
    description='Air Quality prediction monitoring',
    version=1,
    primary_key=['city','street','date','days_before_forecast_day'],
    event_time="date"
)

# %%
monitor_fg.insert(batch_data, wait=True)
# Out:
# Uploading Dataframe: 100.00% |██████████| Rows 6/6 | Elapsed Time: 00:02 | Remaining Time: 00:00
# Launching job: aq_predictions_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1282196/jobs/named/aq_predictions_1_offline_fg_materialization/executions
# 2025-11-12 16:20:09,023 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-11-12 16:20:12,209 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 monitor_fg.insert(batch_data, wait=True)
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/feature_group.py:3153, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, wait, transformation_context, transform)
#    3150 if not self._id and self._offline_backfill_every_hr is not None:
#    3151     write_options["offline_backfill_every_hr"] = self._offline_backfill_every_hr
# -> 3153 job, ge_report = self._feature_group_engine.insert(
#    3154     self,
#    3155     feature_dataframe=feature_dataframe,
#    3156     overwrite=overwrite,
#    3157     operation=operation,
#    3158     storage=storage.lower() if storage is not None else None,
#    3159     write_options=write_options,
#    3160     validation_options={"save_report": True, **validation_options},
#    3161     transformation_context=transformation_context,
#    3162     transform=transform,
#    3163 )
#    3165 if engine.get_type().startswith("spark") and not self.stream:
#    3166     # Also, only compute statistics if stream is False.
#    3167     # if True, the backfill job has not been triggered and the data has not been inserted (it's in Kafka)
#    3168     self.compute_statistics()
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/core/feature_group_engine.py:245, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options, transformation_context, transform)
#     241 if overwrite:
#     242     self._feature_group_api.delete_content(feature_group)
#     244 return (
# --> 245     engine.get_instance().save_dataframe(
#     246         feature_group,
#     247         feature_dataframe,
#     248         "bulk_insert" if overwrite else operation,
#     249         feature_group.online_enabled,
#     250         storage,
#     251         offline_write_options,
#     252         online_write_options,
#     253     ),
#     254     ge_report,
#     255 )
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/engine/python.py:819, in Engine.save_dataframe(self, feature_group, dataframe, operation, online_enabled, storage, offline_write_options, online_write_options, validation_id)
#     804 def save_dataframe(
#     805     self,
#     806     feature_group: FeatureGroup,
#    (...)
#     813     validation_id: Optional[int] = None,
#     814 ) -> Optional[job.Job]:
#     815     if (
#     816         hasattr(feature_group, "EXTERNAL_FEATURE_GROUP")
#     817         and feature_group.online_enabled
#     818     ) or feature_group.stream:
# --> 819         return self._write_dataframe_kafka(
#     820             feature_group, dataframe, offline_write_options
#     821         )
#     822     else:
#     823         # for backwards compatibility
#     824         return self.legacy_save_dataframe(
#     825             feature_group,
#     826             dataframe,
#    (...)
#     832             validation_id,
#     833         )
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/engine/python.py:1605, in Engine._write_dataframe_kafka(self, feature_group, dataframe, offline_write_options)
#    1603         initial_check_point = ""
#    1604     # provide the initial_check_point as it will reduce the read amplification of materialization job
# -> 1605     feature_group.materialization_job.run(
#    1606         args=feature_group.materialization_job.config.get("defaultArgs", "")
#    1607         + (
#    1608             f" -initialCheckPointString {initial_check_point}"
#    1609             if initial_check_point
#    1610             else ""
#    1611         ),
#    1612         await_termination=offline_write_options.get("wait_for_job", False),
#    1613     )
#    1615 # wait for online ingestion
#    1616 if feature_group.online_enabled and offline_write_options.get(
#    1617     "wait_for_online_ingestion", False
#    1618 ):
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hopsworks_common/usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hopsworks_common/job.py:186, in Job.run(self, args, await_termination)
#     182 print(
#     183     f"Job started successfully, you can follow the progress at \n{execution.get_url()}"
#     184 )
#     185 if await_termination:
# --> 186     return self._execution_engine.wait_until_finished(self, execution)
#     187 else:
#     188     return execution
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hopsworks_common/engine/execution_engine.py:126, in ExecutionEngine.wait_until_finished(self, job, execution, timeout)
#     124     self._log.info("The waiting timeout was exceeded.")
#     125     return updated_execution
# --> 126 time.sleep(MAX_LAG)
#     127 updated_execution = self._execution_api._get(job, execution.id)
#     128 if execution_state != updated_execution.state:
#
# KeyboardInterrupt:

# %%
# We will create a hindcast chart for  only the forecasts made 1 day beforehand
monitoring_df = monitor_fg.filter(monitor_fg.days_before_forecast_day == 1).read()
monitoring_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.01s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-15 00:00:00+00:00                 15.2                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25  \
# 0            6.569383                     80.53775  Shanghai       91.209328
#
#              street country  days_before_forecast_day
# 0  Jiading Nanxiang   China                         1

# %%
air_quality_fg = fs.get_feature_group(name='air_quality', version=1)
air_quality_df = air_quality_fg.read()
air_quality_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.11s)
#                           date   pm25 country      city            street  \
# 0    2021-07-06 00:00:00+00:00   47.0   China  Shanghai  Jiading Nanxiang
# 1    2020-12-14 00:00:00+00:00   62.0   China  Shanghai  Jiading Nanxiang
# 2    2020-09-20 00:00:00+00:00  102.0   China  Shanghai  Jiading Nanxiang
# 3    2019-12-24 00:00:00+00:00   88.0   China  Shanghai  Jiading Nanxiang
# 4    2023-12-16 00:00:00+00:00   94.0   China  Shanghai  Jiading Nanxiang
# ...                        ...    ...     ...       ...               ...
# 2576 2021-12-19 00:00:00+00:00  134.0   China  Shanghai  Jiading Nanxiang
# 2577 2023-04-04 00:00:00+00:00   52.0   China  Shanghai  Jiading Nanxiang
# 2578 2019-09-03 00:00:00+00:00   55.0   China  Shanghai  Jiading Nanxiang
# 2579 2019-01-29 00:00:00+00:00  117.0   China  Shanghai  Jiading Nanxiang
# 2580 2019-01-17 00:00:00+00:00  163.0   China  Shanghai  Jiading Nanxiang
#
#                                     url
# 0     https://api.waqi.info/feed/@10208
# 1     https://api.waqi.info/feed/@10208
# 2     https://api.waqi.info/feed/@10208
# 3     https://api.waqi.info/feed/@10208
# 4     https://api.waqi.info/feed/@10208
# ...                                 ...
# 2576  https://api.waqi.info/feed/@10208
# 2577  https://api.waqi.info/feed/@10208
# 2578  https://api.waqi.info/feed/@10208
# 2579  https://api.waqi.info/feed/@10208
# 2580  https://api.waqi.info/feed/@10208
#
# [2581 rows x 6 columns]

# %%
outcome_df = air_quality_df[['date', 'pm25']]
preds_df =  monitoring_df[['date', 'predicted_pm25']]

hindcast_df = pd.merge(preds_df, outcome_df, on="date")
hindcast_df = hindcast_df.sort_values(by=['date'])

# If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
if len(hindcast_df) == 0:
    hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
hindcast_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.10s)
# Uploading Dataframe: 100.00% |██████████| Rows 4/4 | Elapsed Time: 00:01 | Remaining Time: 00:00
# 2025-11-12 16:20:59,935 WARNING: UserWarning: Materialization job is already running, aborting new execution.Please wait for the current execution to finish before triggering a new one.You can check the status of the current execution using `fg.materialization_job.get_state()`.or `fg.materialization_job.get_final_state()` or check it out in the Hopsworks UI.at https://c.app.hopsworks.ai:443/p/1282196/jobs/named/aq_predictions_1_offline_fg_materialization.
# Use fg.materialization_job.run(args=-op offline_fg_materialization -path hdfs:///Projects/airconditiondetection/Resources/jobs/aq_predictions_1_offline_fg_materialization/config_1762957432583) to trigger the materialization job again.
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-09 00:00:00+00:00            16.867418                0.2
# 1 2025-11-10 00:00:00+00:00            15.106999                1.0
# 2 2025-11-11 00:00:00+00:00            15.706998                0.0
# 3 2025-11-12 00:00:00+00:00            16.450001                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25  \
# 0           13.346729                     5.440223  Shanghai      105.670822
# 1           13.684735                    29.755941  Shanghai      110.179649
# 2           15.833861                    40.487221  Shanghai       75.178497
# 3           11.440978                    12.724360  Shanghai      108.070190
#
#    pm25            street country  days_before_forecast_day
# 0  65.0  Jiading Nanxiang   China                         1
# 1  81.0  Jiading Nanxiang   China                         1
# 2  28.0  Jiading Nanxiang   China                         1
# 3  63.0  Jiading Nanxiang   China                         1

# %% [markdown]
# ### Plot the Hindcast comparing predicted with forecasted values (1-day prior forecast)
#
# __This graph will be empty to begin with - this is normal.__
#
# After a few days of predictions and observations, you will get data points in this graph.

# %%
hindcast_file_path = f"{root_dir}/docs/air-quality/assets/img/pm25_hindcast_1day.png"
plt = util.plot_air_quality_forecast(city, street, hindcast_df, hindcast_file_path, hindcast=True)
plt.show()

# %% [markdown]
# ### Upload the prediction and hindcast dashboards (png files) to Hopsworks

# %%
dataset_api = project.get_dataset_api()
str_today = today.strftime("%Y-%m-%d")
if dataset_api.exists("Resources/airquality") == False:
    dataset_api.mkdir("Resources/airquality")
dataset_api.upload(pred_file_path, f"Resources/airquality/{city}_{street}_{str_today}", overwrite=True)
dataset_api.upload(hindcast_file_path, f"Resources/airquality/{city}_{street}_{str_today}", overwrite=True)

proj_url = project.get_url()
print(f"See images in Hopsworks here: {proj_url}/settings/fb/path/Resources/airquality")
# Out:
# Uploading /Users/pppanda/mlfs-book/docs/air-quality/assets/img/pm25_forecast.png: 0.000%|          | 0/42389 e…
# Uploading /Users/pppanda/mlfs-book/docs/air-quality/assets/img/pm25_hindcast_1day.png: 0.000%|          | 0/51…
# See images in Hopsworks here: https://c.app.hopsworks.ai:443/p/1282196/settings/fb/path/Resources/airquality

# %% [markdown]
# ---
